# %% [markdown]
# # 04 Evaluation and Error Analysis
#
# This notebook reviews held-out test results produced by `python -m src.evaluate`.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
test_metrics_path = root / "results" / "test_metrics.csv"
plots = root / "results" / "plots"

test_metrics = pd.read_csv(test_metrics_path)
test_metrics

# %% [markdown]
# False negatives are important because a missed machine failure can be costly. The confusion matrix gives the most direct error summary.

# %%
for filename in ["confusion_matrix.png", "feature_importance.png"]:
    print(filename)
    display(Image(filename=str(plots / filename)))
