# %% [markdown]
# # 02 Preprocessing and EDA
#
# This notebook reviews the processed dataset and displays EDA outputs generated by `python -m src.eda`.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
processed_path = root / "data" / "processed" / "ai4i_processed.csv"
missing_path = root / "results" / "missing_values_summary.csv"
plots = root / "results" / "plots"

df = pd.read_csv(processed_path)
df.head()

# %%
pd.read_csv(missing_path)

# %%
for filename in [
    "class_balance.png",
    "feature_distributions.png",
    "correlation_heatmap.png",
    "target_vs_features.png",
    "failure_mode_counts.png",
]:
    print(filename)
    display(Image(filename=str(plots / filename)))
