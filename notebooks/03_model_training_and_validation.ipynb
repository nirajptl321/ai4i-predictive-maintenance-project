# %% [markdown]
# # 03 Model Training and Validation
#
# This notebook reads validation results produced by `python -m src.train`. Model training and tuning logic is kept in `src/modeling.py` and `src/train.py`.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
metrics_path = root / "results" / "metrics_table.csv"
plots = root / "results" / "plots"

metrics = pd.read_csv(metrics_path)
metrics

# %%
selected = metrics.sort_values(["f1_score", "recall", "f2_score", "roc_auc"], ascending=False).iloc[0]
selected[["model", "f1_score", "recall", "f2_score", "roc_auc", "best_params"]]

# %%
display(Image(filename=str(plots / "model_comparison.png")))
